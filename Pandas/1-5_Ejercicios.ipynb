# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
datos = [2,3,4,5,7,11]

# %%
serie=pd.Series(datos)

# %%
serie
# Out:
# 0     2
# 1     3
# 2     4
# 3     5
# 4     7
# 5    11
# dtype: int64

# %% [markdown]
# ver la cantidad de datos en la serie

# %%
serie.size
# Out:
# 6

# %% [markdown]
# ver valores estadisticos de la serie

# %%
serie.describe()
# Out:
# count     6.000000
# mean      5.333333
# std       3.265986
# min       2.000000
# 25%       3.250000
# 50%       4.500000
# 75%       6.500000
# max      11.000000
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
elemetos = [2,3,5,7,11]

# %%
type(elemetos)
# Out:
# list

# %%
serie = pd.Series(elemetos)

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ya converti la lista elemetos en una serie
#
# ahora convertire la serie en lista

# %%
lista = serie.tolist()

# %%
type(lista)
# Out:
# list

# %%
lista
# Out:
# [2, 3, 5, 7, 11]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
serie1 = pd.Series([1,2,3,4,5])
serie2 = pd.Series([9,8,7,6,5])

# %%
serie1 + serie2
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# dtype: int64

# %%
serie1 - serie2
# Out:
# 0   -8
# 1   -6
# 2   -4
# 3   -2
# 4    0
# dtype: int64

# %%
serie1 * serie2
# Out:
# 0     9
# 1    16
# 2    21
# 3    24
# 4    25
# dtype: int64

# %%
serie1 / serie2
# Out:
# 0    0.111111
# 1    0.250000
# 2    0.428571
# 3    0.666667
# 4    1.000000
# dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
serieA = pd.Series([1,2,3,5,7])
serieB = pd.Series([13,17,11,5,3])

# %%
serieA
# Out:
# 0    1
# 1    2
# 2    3
# 3    5
# 4    7
# dtype: int64

# %%
serieB
# Out:
# 0    13
# 1    17
# 2    11
# 3     5
# 4     3
# dtype: int64

# %% [markdown]
# ahora utilizare los signos de comparacion;
#
# la comparacion la hace elemento a elemento, asi que las series tienen que tener la misma cantidad de elementos

# %%
serieA < serieB
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
serieA > serieB
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
serieA == serieB
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
